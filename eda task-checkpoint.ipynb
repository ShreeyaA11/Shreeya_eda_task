# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
steam_games_df=pd.read_csv("C:\\Users\\Shreeya\\Desktop\\eda task\\merged_data.csv")

# %%
steam_games_df.shape
# Out:
# (71700, 16)

# %%
steam_games_df.isnull().sum()
# Out:
# Title                         1
# Original Price                0
# Discounted Price              0
# Release Date                131
# Link                          0
# Game Description            211
# Recent Reviews Summary    15220
# All Reviews Summary       66329
# Recent Reviews Number     15220
# All Reviews Number        66329
# Developer                   221
# Publisher                   517
# Supported Languages           0
# Popular Tags                  0
# Game Features                 0
# Minimum Requirements       1124
# dtype: int64

# %% [markdown]
# steam_games_df.dtypes

# %%
steam_games_df.dtypes
# Out:
# Title                     object
# Original Price            object
# Discounted Price          object
# Release Date              object
# Link                      object
# Game Description          object
# Recent Reviews Summary    object
# All Reviews Summary       object
# Recent Reviews Number     object
# All Reviews Number        object
# Developer                 object
# Publisher                 object
# Supported Languages       object
# Popular Tags              object
# Game Features             object
# Minimum Requirements      object
# dtype: object

# %%
steam_games_df.sample(10)
# Out:
#                                                    Title Original Price  \
# 3116   Agatha Christie - Hercule Poirot: The First Cases         $14.99
# 32100                          Clicker: Mining Simulator          $1.39
# 71564                                          Scavenger           Free
# 21985                       Adventures at the North Pole          $6.29
# 59565                                  The Blood Eclipse          $2.69
# 21120                                      Love on Paper          $3.29
# 58890                         Frisky Business: Episode 2           Free
# 7159                                     Rampage Knights          $7.49
# 1298                            The Jackbox Party Pack 4         $12.49
# 71127                                             DENDAM           Free
#
#       Discounted Price  Release Date  \
# 3116            $14.99  27 Sep, 2021
# 32100            $1.39  18 Jan, 2018
# 71564             Free  26 Mar, 2023
# ...

# %%
print(steam_games_df[steam_games_df['Title'].isna()]['Game Description'])
steam_games_df[steam_games_df['Title'].isna()]
# Out:
# 56954    NaN
# Name: Game Description, dtype: object
#       Title Original Price Discounted Price Release Date  \
# 56954   NaN           Free             Free          NaN
#
#                                                     Link Game Description  \
# 56954  https://store.steampowered.com/sub/418/?snr=1_...              NaN
#
#       Recent Reviews Summary All Reviews Summary Recent Reviews Number  \
# 56954                    NaN                 NaN                   NaN
#
#       All Reviews Number Developer Publisher Supported Languages Popular Tags  \
# 56954                NaN       NaN       NaN                  []           []
#
#       Game Features Minimum Requirements
# 56954            []                  NaN
